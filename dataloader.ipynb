# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

import tensorflow as tf
import tensorflow.keras as keras
import numpy as np
import matplotlib.pyplot as plt
import cv2
import pickle

from covidimage import CovidImage

# %%
path = "data"
train_file = "data/train_split_v3.txt"
test_file = "data/test_split_v3.txt"

dataloader = CovidImage(path, train_file, test_file)

# %%
# dataloader._process_train_set()
# dataloader._process_test_set()

trainX, train_y, testX, test_y = dataloader.load_data()
# Out:
# Could not find pickled traning data
# Processing train set
# Processed 1000 images of 13640
# Processed 2000 images of 13640
# Processed 3000 images of 13640
# Processed 4000 images of 13640
# Processed 5000 images of 13640
# Processed 6000 images of 13640
# Processed 7000 images of 13640
# Processed 8000 images of 13640
# Processed 9000 images of 13640
# Processed 10000 images of 13640
# Processed 11000 images of 13640
# Processed 12000 images of 13640
# Processed 13000 images of 13640
# Done with train data
# Could not find pickled test data
# Processing test set
# Processed 1000 images of 1510
# Done with test data
# Loading done

# %%
plt.imshow(dataloader.testX[0])

# %%
tf.__version__
# Out:
# '2.0.0-beta1'

# %%
trainX.shape
# Out:
# (13640, 224, 224)
